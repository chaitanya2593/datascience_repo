# %%
employee_count = [100, 1000, 10000, 100000, 1000000]

for i in range(model.shape[0]):
    alpha = model.iloc[i]["px_fit_results"].params[0]
    beta = model.iloc[i]["px_fit_results"].params[1]
    
    print("NACEL1 {} -> {}:".format(model.iloc[i]["NACEL1_sector"],model.iloc[i]["Description"]))
    for elem in employee_count:
        emissions = (beta*elem)+alpha
        print("\tFor Employee count: {}, emissions is {}".format(elem,emissions)) 
    
    print('\n')
# Out:
# NACEL1 C -> MANUFACTURING:
# 	For Employee count: 100, emissions is 3990.747502287503
# 	For Employee count: 1000, emissions is 3995.9831221289446
# 	For Employee count: 10000, emissions is 4048.339320543362
# 	For Employee count: 100000, emissions is 4571.901304687541
# 	For Employee count: 1000000, emissions is 9807.521146129322
#
#
# NACEL1 K -> FINANCIAL AND INSURANCE ACTIVITIES:
# 	For Employee count: 100, emissions is 1876.021559922694
# 	For Employee count: 1000, emissions is 1860.3760152229556
# 	For Employee count: 10000, emissions is 1703.9205682255717
# 	For Employee count: 100000, emissions is 139.36609825173286
# 	For Employee count: 1000000, emissions is -15506.178601486657
#
#
# NACEL1 H -> TRANSPORTATION AND STORAGE:
# 	For Employee count: 100, emissions is 10080.757381587586
# 	For Employee count: 1000, emissions is 10080.871550480866
# 	For Employee count: 10000, emissions is 10082.013239413664
# 	For Employee count: 100000, emissions is 10093.430128741642
# ...
